# %%
#live fake news detection from NDTV RSS Feed

#part 1: Imports
import pandas as pd
import numpy as np
import re
import string
import joblib
import feedparser
import requests
import os

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,accuracy_score
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import train_test_split


import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\acer\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
#part 2: preprocessing function
def clean_text(text):
    text=text.lower()
    text=re.sub(r"https?://\S+","",text) #remove urls
    text=re.sub(r"[^a-zA-Z\s]","",text) #remove punctuation
    text=''.join([c for c in text if c not in string.punctuation])
    words=text.split()
    stop_words=set(stopwords.words('english'))
    lemmatizer=WordNetLemmatizer()
    cleaned=[lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(cleaned)
#Loading fake news dataset 
def load_local_dataset():
    path="fake_news_dataset.csv"
    df=pd.read_csv(path)
    df=df[['text','label']]
    df.dropna(inplace=True)
    df['label']=df['label'].str.upper()
    return df

# %%
#part 6: Fetch live news from NDTV RSS Feed
def fetch_ndtv_news():
    feed_url='https://feeds.feedburner.com/ndtvnews-top-stories'
    feed=feedparser.parse(feed_url)
    news_items=[]
    for entry in feed.entries:
        title=entry.title
        summary=entry.summary if 'summary' in entry else title 
        combined=f"{title}.{summary}"
        news_items.append({'text': combined,'label':'REAL'})

    return pd.DataFrame(news_items)

#combine and clean
def prepare_data():
    local_df=load_local_dataset()
    ndtv_df=fetch_ndtv_news()
    combined=pd.concat([local_df,ndtv_df],ignore_index=True)
    combined['clean_text']=combined['text'].apply(clean_text)
    return combined.dropna()

# %%
#Tain and save model 
def train_and_save_model(df):
    vectorizer=TfidfVectorizer(max_features=10000,ngram_range=(1,2))
    X=vectorizer.fit_transform(df['clean_text'])
    y=df['label']
    X_train,X_test,y_train,y_test=train_test_split(X,y,stratify=y,test_size=0.2,random_state=42)
    model=LogisticRegression(max_iter=1000,class_weight='balanced')
    model.fit(X_train,y_train)
    joblib.dump(model,"updated_model.pkl")
    joblib.dump(vectorizer,"udated_vectorizer.pkl")
    print("Model and Vectorizer saved as 'updated_model.pkl' and updated_vectorizer.pkl")
    print("Evaluation:")
    from sklearn.metrics import classification_report,accuracy_score
    y_pred=model.predict(X_test)
    print("Accuracy:",accuracy_score(y_test,y_pred))
    print(classification_report(y_test,y_pred))

# %%
# Calling Main 
if __name__=="__main__":
    print("Preparing data....")
    combined_df=prepare_data()
    print("Training model...")
    train_and_save_model(combined_df)
# Out:
# Preparing data....
# Training model...
# Model and Vectorizer saved as 'updated_model.pkl' and updated_vectorizer.pkl
# Evaluation:
# Accuracy: 1.0
#               precision    recall  f1-score   support
#
#         FAKE       1.00      1.00      1.00       120
#         REAL       1.00      1.00      1.00       124
#
#     accuracy                           1.00       244
#    macro avg       1.00      1.00      1.00       244
# weighted avg       1.00      1.00      1.00       244

# %%
#Load model and vectorizer 
model=joblib.load("updated_model.pkl")
vectorizer=joblib.load("udated_vectorizer.pkl")
#Cleaning Function
def clean_text(text):
    text=text.lower()
    text=re.sub(r"https?://\S+","",text) #remove urls
    text=re.sub(r"[^a-zA-Z\s]","",text) #remove punctuation
    text=''.join([c for c in text if c not in string.punctuation])
    words=text.split()
    stop_words=set(stopwords.words('english'))
    lemmatizer=WordNetLemmatizer()
    cleaned=[lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    return ' '.join(cleaned)

# %%
def fetch_ndtv_news():
    feed_url='https://feeds.feedburner.com/ndtvnews-top-stories'
    feed=feedparser.parse(feed_url)
    news_items=[]
    for entry in feed.entries:
        title=entry.title
        summary=entry.summary if 'summary' in entry else title 
        link=entry.link
        text=f"{title}.{summary}"
        news_items.append({'title': title ,'summary':summary,'link':link,'full_text':text})
        

    return news_items

# %%
#Analyze news items 
def analyze_news(news_items):
    result=[]
    for item in news_items:
        cleaned=clean_text(item['full_text'])
        vect=vectorizer.transform([cleaned])
        prediction=model.predict(vect)[0]
        proba=model.predict_proba(vect)[0]
        score=int(proba.max()*100)
        label=prediction if score >=70 else "uncertain"
        result.append({
        'title':item['title'],
        'link':item['link'],
        'label':label,
        'confidence':score,
        'immunization_score':100-score
        })
    return result

# %%
if __name__=='__main__' :
    live_news=fetch_ndtv_news()
    analyzed =analyze_news(live_news)
    for item in analyzed:
        print(f"Title:{item['title']}")
        print(f"Link:{item['link']})")
        print(f"Prediction:{item['label']}")
        print(f"Confidence:{item['confidence']}%")
        print(f"Immunization Score:{item['immunization_score']}")
        print("-"*80)
# Out:
# Title:Why US Health Secretary RFK Jr Fired Entire Vaccine Advisory Panel
# Link:https://www.ndtv.com/world-news/why-us-health-secretary-rfk-jr-fired-entire-vaccine-advisory-panel-8630105#publisher=newsstand)
# Prediction:REAL
# Confidence:71%
# Immunization Score:29
# --------------------------------------------------------------------------------
# Title:Goa Minister Must Apologise Publicly Else We Will Go On Strike, Warns Doctor
# Link:https://www.ndtv.com/india-news/goa-doctor-rudresh-kuttikar-says-vishwajit-rane-must-issue-a-public-apology-immediately-8629795#publisher=newsstand)
# Prediction:uncertain
# Confidence:65%
# Immunization Score:35
# --------------------------------------------------------------------------------
# Title:Trump Sends Thousands Of More Troops To LA As Immigration Protests Intensify
# Link:https://www.ndtv.com/world-news/los-angeles-news-trump-sends-thousands-of-more-troops-to-la-as-immigration-protests-intensify-8629672#publisher=newsstand)
# Prediction:REAL
# Confidence:71%
# Immunization Score:29
# --------------------------------------------------------------------------------
# Title:Indian Man Handcuffed, Pinned To Floor At US Airport, India Embassy Responds
# Link:https://www.ndtv.com/world-news/indian-man-handcuffed-pinned-to-floor-at-us-airport-india-embassy-responds-8629948#publisher=newsstand)
# Prediction:uncertain
# Confidence:64%
# Immunization Score:36
# --------------------------------------------------------------------------------
# Title:Why Most-Followed TikToker Khaby Lame Was Detained By US Immigration
# Link:https://www.ndtv.com/world-news/why-most-followed-tiktoker-khaby-lame-was-detained-by-us-immigration-8629979#publisher=newsstand)
# Prediction:REAL
# Confidence:70%
# Immunization Score:30
# --------------------------------------------------------------------------------
# Title:Everything New Coming to iPhones, iPads and Macs Later This Year
# Link:https://www.ndtv.com/world-news/everything-new-coming-to-iphones-ipads-and-macs-later-this-year-8629827#publisher=newsstand)
# Prediction:REAL
# Confidence:71%
# Immunization Score:29
# --------------------------------------------------------------------------------
# Title:"Careless Dumping Days Behind Us": Delhi To Get India's 1st E-Waste Eco Park
# Link:https://www.ndtv.com/delhi-news/days-of-careless-dumping-behind-us-delhi-to-launch-e-waste-eco-park-in-holambi-kalan-8629673#publisher=newsstand)
# Prediction:REAL
# Confidence:70%
# Immunization Score:30
# --------------------------------------------------------------------------------
# Title:Raja Raghuvanshi Hit On Front And Back Of Head: Honeymoon Murder Autopsy
# Link:https://www.ndtv.com/india-news/raja-raghuvanshi-hit-on-front-of-head-on-back-honeymoon-murder-autopsy-8624530#publisher=newsstand)
# Prediction:uncertain
# Confidence:69%
# Immunization Score:31
# --------------------------------------------------------------------------------
# Title:Trump Says Meeting On Iran Planned For Thursday
# Link:https://www.ndtv.com/world-news/trump-says-meeting-on-iran-planned-for-thursday-8628642#publisher=newsstand)
# Prediction:REAL
# Confidence:71%
# Immunization Score:29
# --------------------------------------------------------------------------------
# Title:Gaza's Al-Amal Hospital "Virtually Out Of Service": WHO
# Link:https://www.ndtv.com/world-news/gazas-al-amal-hospital-virtually-out-of-service-who-8629539#publisher=newsstand)
# Prediction:REAL
# Confidence:70%
# Immunization Score:30
# --------------------------------------------------------------------------------
# Title:Russia's New Drone Strikes Hit Kyiv, Maternity Ward In Odesa: Ukraine
# Link:https://www.ndtv.com/world-news/russias-new-drone-strikes-hit-kyiv-maternity-ward-in-odesa-ukraine-8629504#publisher=newsstand)
# Prediction:REAL
# Confidence:71%
# Immunization Score:29
# --------------------------------------------------------------------------------
# Title:Trump Says Iran Is Involved In Gaza Hostage Negotiations
# Link:https://www.ndtv.com/world-news/donald-trump-says-iran-is-involved-in-gaza-hostage-negotiations-8629468#publisher=newsstand)
# Prediction:REAL
# Confidence:72%
# Immunization Score:28
# --------------------------------------------------------------------------------
# Title:Left Parties Write To PM Opposing Anti-Maoist Operation In Chhattisgarh
# Link:https://www.ndtv.com/india-news/five-left-parties-write-to-pm-modi-opposing-anti-maoist-operation-in-chhattisgarh-8628797#publisher=newsstand)
# Prediction:REAL
# Confidence:70%
# Immunization Score:30
# --------------------------------------------------------------------------------
# Title:"In Touch With Authorities": Indian Consulate In US On Man Facing Difficulties At Airport
# Link:https://www.ndtv.com/world-news/indian-consulate-in-us-on-indian-man-facing-difficulties-at-newark-liberty-international-airport-8629379#publisher=newsstand)
# Prediction:REAL
# Confidence:70%
# Immunization Score:30
# --------------------------------------------------------------------------------
# Title:UN Says Most Flour Delivered In Gaza Looted Or Taken By Starving People
# Link:https://www.ndtv.com/world-news/un-says-most-flour-delivered-in-gaza-looted-or-taken-by-starving-people-8629297#publisher=newsstand)
# Prediction:REAL
# Confidence:73%
# Immunization Score:27
# --------------------------------------------------------------------------------
# Title:"I Don't Want Civil War, But...": Trump Slams California Governor Amid LA Clashes
# Link:https://www.ndtv.com/world-news/donald-trump-slams-california-governor-amid-la-clashes-8629263#publisher=newsstand)
# Prediction:REAL
# Confidence:71%
# Immunization Score:29
# --------------------------------------------------------------------------------
# Title:Nuclear Watchdog Warns Iran Against Israeli Strikes On Nuke Facilities
# Link:https://www.ndtv.com/world-news/nuclear-watchdog-warns-iran-against-israeli-strikes-on-nuke-facilities-8629229#publisher=newsstand)
# Prediction:uncertain
# Confidence:64%
# Immunization Score:36
# --------------------------------------------------------------------------------
# Title:Drugs Worth Rs 45 Crore Seized In Assam; 4 Arrested
# Link:https://www.ndtv.com/india-news/drugs-worth-rs-45-crore-seized-in-assam-4-arrested-8629137#publisher=newsstand)
# Prediction:REAL
# Confidence:70%
# Immunization Score:30
# --------------------------------------------------------------------------------
# Title:Sly Stone, Leader Of 1960s Funk Band, Dies At 82
# Link:https://www.ndtv.com/world-news/sly-stone-leader-of-1960s-funk-band-dies-at-82-8629106#publisher=newsstand)
# Prediction:REAL
# Confidence:70%
# Immunization Score:30
# --------------------------------------------------------------------------------
# Title:US Military To Deploy 700 Marines To Los Angeles As Protests Intensify
# Link:https://www.ndtv.com/world-news/us-military-to-deploy-700-marines-to-los-angeles-as-protests-intensify-8629078#publisher=newsstand)
# Prediction:uncertain
# Confidence:69%
# Immunization Score:31
# --------------------------------------------------------------------------------
